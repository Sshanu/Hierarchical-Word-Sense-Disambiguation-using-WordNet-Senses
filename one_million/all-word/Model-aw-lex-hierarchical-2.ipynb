# %% [markdown]
# ### hierarchical + convolution for extracting features using word embeddings
# #### batch size = 128, learning rate = 0.001, kernel size =  5, num_gpus = 6

# %%
import tensorflow as tf
tf.logging.set_verbosity(tf.logging.WARN)
import pickle
import numpy as np
import os
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
import os
from tensorflow.python.client import device_lib
from collections import Counter
import time

VERY_BIG_NUMBER = 1e30

# %%
f = open('../../Glove/word_embedding_glove', 'rb')
word_embedding = pickle.load(f)
f.close()

word_embedding = word_embedding[: len(word_embedding)-1]

f = open('../../Glove/vocab_glove', 'rb')
vocab = pickle.load(f)
f.close()

word2id = dict((w, i) for i,w in enumerate(vocab))
id2word = dict((i, w) for i,w in enumerate(vocab))

unknown_token = "UNKNOWN_TOKEN"

# Model Description  
model_name = 'model-aw-lex-hierarchical-2'
model_dir = '../output/all-word/' + model_name
save_dir = os.path.join(model_dir, "save/")
log_dir = os.path.join(model_dir, "log")

if not os.path.exists(model_dir):
    os.mkdir(model_dir)
if not os.path.exists(save_dir):
    os.mkdir(save_dir)
if not os.path.exists(log_dir):
    os.mkdir(log_dir)

with open('../../../dataset/train_val_data_fine/hierarchical_all_word_lex','rb') as f:
    train_data, val_data = pickle.load(f)    


with open('../../../dataset/test_data_fine/hierarchical_all_word_lex','rb') as f:
    test_data = pickle.load(f)  
    
with open('../../../dataset/train_val_data_fine/mask_mat_lex','rb') as f:
    mask_mat = pickle.load(f)    
    
# Parameters
mode = 'train'
num_senses = 44
num_pos = 12
num_sense_pos = 4
batch_size = 128
vocab_size = len(vocab)
unk_vocab_size = 1
word_emb_size = len(word_embedding[0])
max_sent_size = 200
hidden_size = 256
num_filter = 256
window_size = 5
kernel_size = 5
keep_prob = 0.3
l2_lambda = 0.001
init_lr = 0.001
decay_steps = 500
decay_rate = 0.99
clip_norm = 1
clipping = True
crf_lambda = 0.05
moving_avg_deacy = 0.999
num_gpus = 6
width = int(window_size/2)

# %%
def average_gradients(tower_grads):
    average_grads = []
    for grad_and_vars in zip(*tower_grads):
        # Note that each grad_and_vars looks like the following:
        #   ((grad0_gpu0, var0_gpu0), ... , (grad0_gpuN, var0_gpuN))
        grads = []
        for g, _ in grad_and_vars:
            # Add 0 dimension to the gradients to represent the tower.
            expanded_g = tf.expand_dims(g, 0)

            # Append on a 'tower' dimension which we will average over below.
            grads.append(expanded_g)

        # Average over the 'tower' dimension.
        grad = tf.concat(grads, 0)
        grad = tf.reduce_mean(grad, axis=0)

        # Keep in mind that the Variables are redundant because they are shared
        # across towers. So .. we will just return the first tower's pointer to
        # the Variable.
        v = grad_and_vars[0][1]
        grad_and_var = (grad, v)
        average_grads.append(grad_and_var)
    return average_grads

# %%
# MODEL
device_num = 0
tower_grads = []
losses = []
predictions = []
predictions_pos = []
total_trans_params = []

x = tf.placeholder('int32', [num_gpus, batch_size, max_sent_size], name="x")
y = tf.placeholder('int32', [num_gpus, batch_size, max_sent_size], name="y")
y_sp = tf.placeholder('int32', [num_gpus, batch_size, max_sent_size], name="y_sp")
y_pos = tf.placeholder('int32', [num_gpus, batch_size, max_sent_size], name="y_pos")
x_mask  = tf.placeholder('bool', [num_gpus, batch_size, max_sent_size], name='x_mask') 
sense_mask  = tf.placeholder('bool', [num_gpus, batch_size, max_sent_size], name='sense_mask')
is_train = tf.placeholder('bool', [], name='is_train')
word_emb_mat = tf.placeholder('float', [None, word_emb_size], name='emb_mat')
input_keep_prob = tf.cond(is_train,lambda:keep_prob, lambda:tf.constant(1.0))
pretrain = tf.placeholder('bool', [], name="pretrain")
mask_matrix = tf.tile(tf.expand_dims(tf.constant(value=mask_mat, shape=list(np.array(mask_mat).shape), dtype='float32'), 0), [batch_size, 1, 1]) 

global_step = tf.Variable(0, trainable=False, name="global_step")
learning_rate = tf.train.exponential_decay(init_lr, global_step, decay_steps, decay_rate, staircase=True)
summaries = []

def local_attention(input_x, input_mask, W_att):
    flat_x = tf.reshape(input_x, [-1, tf.shape(input_x)[2]])
    h_tanh = tf.tanh(flat_x)
    u_flat = tf.matmul(h_tanh, W_att) 
    u = tf.reshape(u_flat, [batch_size, -1]) + input_mask
    a = tf.expand_dims(tf.nn.softmax(u, 1), 2)
    c = tf.reduce_sum(tf.multiply(input_x, a), axis=1)  
    return c

def global_attention(input_x, input_mask, W_att):
    flat_x = tf.reshape(input_x, [batch_size*max_sent_size, tf.shape(input_x)[2]])
    h_tanh = tf.tanh(flat_x)
    u_flat = tf.matmul(h_tanh, W_att) 
    u = tf.reshape(u_flat, [batch_size, max_sent_size]) + input_mask
    a = tf.expand_dims(tf.nn.softmax(u, 1), 2)
    c = tf.reduce_sum(tf.multiply(input_x, a), axis=1)  
    return c

with tf.variable_scope("word_embedding"):
    unk_word_emb_mat = tf.get_variable("word_emb_mat", dtype='float', shape=[unk_vocab_size, word_emb_size], initializer=tf.contrib.layers.xavier_initializer(uniform=True, seed=0, dtype=tf.float32))
    final_word_emb_mat = tf.concat([word_emb_mat, unk_word_emb_mat], 0)

with tf.variable_scope(tf.get_variable_scope()):
    for gpu_idx in range(num_gpus):
        if gpu_idx>=3:
            device_num = 1
        with tf.name_scope("model_{}".format(gpu_idx)) as scope, tf.device('/gpu:%d' % device_num):

            if gpu_idx > 0:
                    tf.get_variable_scope().reuse_variables()

            with tf.name_scope("word"):
                Wx = tf.nn.embedding_lookup(final_word_emb_mat, x[gpu_idx])  

            float_x_mask = tf.cast(x_mask[gpu_idx], 'float')
            x_len = tf.reduce_sum(tf.cast(x_mask[gpu_idx], 'int32'), axis=1)
            
            tile_x_mask = tf.tile(tf.expand_dims(float_x_mask, 2), [1, 1, word_emb_size])
            Wx_masked = tf.multiply(Wx, tile_x_mask)
            
            with tf.variable_scope("convolution"):
                conv1 = tf.layers.conv1d(inputs=Wx_masked, filters=num_filter, kernel_size=[kernel_size], padding='same', activation=tf.nn.relu)
                conv2 = tf.layers.conv1d(inputs=conv1, filters=num_filter, kernel_size=[kernel_size], padding='same')
                
            with tf.variable_scope("lstm1"):
                cell_fw1 = tf.contrib.rnn.BasicLSTMCell(hidden_size,state_is_tuple=True)
                cell_bw1 = tf.contrib.rnn.BasicLSTMCell(hidden_size,state_is_tuple=True)

                d_cell_fw1 = tf.contrib.rnn.DropoutWrapper(cell_fw1, input_keep_prob=input_keep_prob)
                d_cell_bw1 = tf.contrib.rnn.DropoutWrapper(cell_bw1, input_keep_prob=input_keep_prob)

                (fw_h1, bw_h1), _ = tf.nn.bidirectional_dynamic_rnn(d_cell_fw1, d_cell_bw1, conv2, sequence_length=x_len, dtype='float', scope='lstm1')
                h1 = tf.concat([fw_h1, bw_h1], 2)

            with tf.variable_scope("lstm2"):
                cell_fw2 = tf.contrib.rnn.BasicLSTMCell(hidden_size,state_is_tuple=True)
                cell_bw2 = tf.contrib.rnn.BasicLSTMCell(hidden_size,state_is_tuple=True)

                d_cell_fw2 = tf.contrib.rnn.DropoutWrapper(cell_fw2, input_keep_prob=input_keep_prob)
                d_cell_bw2 = tf.contrib.rnn.DropoutWrapper(cell_bw2, input_keep_prob=input_keep_prob)

                (fw_h2, bw_h2), _ = tf.nn.bidirectional_dynamic_rnn(d_cell_fw2, d_cell_bw2, h1, sequence_length=x_len, dtype='float', scope='lstm2')
                h = tf.concat([fw_h2, bw_h2], 2)
                
            attention_mask = (tf.cast(x_mask[gpu_idx], 'float') -1)*VERY_BIG_NUMBER 

            with tf.variable_scope("global_attention"):
                W_att_global = tf.get_variable("W_att_global", shape=[2*hidden_size, 1], initializer=tf.truncated_normal_initializer(mean=0.0, stddev=0.1, seed=gpu_idx*10))
                flat_h = tf.reshape(h, [batch_size*max_sent_size, tf.shape(h)[2]])
                h_tanh = tf.tanh(flat_h)
                u_flat = tf.matmul(h_tanh, W_att_global) 
                u = tf.reshape(u_flat, [batch_size, max_sent_size]) + attention_mask
                a = tf.expand_dims(tf.nn.softmax(u, 1), 2)
                c = tf.reduce_sum(tf.multiply(h, a), axis=1)
                c_final = tf.tile(tf.expand_dims(c, 1), [1, max_sent_size, 1])
                h_final = tf.concat([c_final, h], 2)
                flat_h_final = tf.reshape(h_final, [batch_size*max_sent_size, tf.shape(h_final)[2]])
                       
            with tf.variable_scope("hidden_layer"):
                W = tf.get_variable("W", shape=[4*hidden_size, 2*hidden_size], initializer=tf.truncated_normal_initializer(mean=0.0, stddev=0.1, seed=gpu_idx*20))
                b = tf.get_variable("b", shape=[2*hidden_size], initializer=tf.zeros_initializer())
                drop_flat_h_final = tf.nn.dropout(flat_h_final, input_keep_prob)
                flat_hl = tf.matmul(drop_flat_h_final, W) + b
            
            with tf.variable_scope("softmax_layer_pos"):
                W = tf.get_variable("W", shape=[2*hidden_size, num_pos], initializer=tf.truncated_normal_initializer(mean=0.0, stddev=0.1, seed=gpu_idx*30))
                b = tf.get_variable("b", shape=[num_pos], initializer=tf.zeros_initializer())
                flat_h1 = tf.reshape(h1, [-1, tf.shape(h1)[2]])
                drop_flat_hl = tf.nn.dropout(flat_hl, input_keep_prob)
                flat_logits_pos = tf.matmul(drop_flat_hl, W) + b
                logits_pos = tf.reshape(flat_logits_pos, [batch_size, max_sent_size, num_pos])
                log_likelihood, trans_params = tf.contrib.crf.crf_log_likelihood(logits_pos, y_pos[gpu_idx], x_len)
                loss_pos = crf_lambda*tf.reduce_mean(-log_likelihood)
                predictions_pos.append(logits_pos)
                total_trans_params.append(trans_params)
                hierarchy = tf.matmul(logits_pos[:, :, :num_sense_pos], mask_matrix)
                
            with tf.variable_scope("softmax_layer"):
                W = tf.get_variable("W", shape=[2*hidden_size, num_senses], initializer=tf.truncated_normal_initializer(mean=0.0, stddev=0.1, seed=gpu_idx*20))
                b = tf.get_variable("b", shape=[num_senses], initializer=tf.zeros_initializer())
                drop_flat_hl = tf.nn.dropout(flat_hl, input_keep_prob)
                flat_logits_sense = tf.matmul(drop_flat_hl, W) + b
                logits_org = tf.reshape(flat_logits_sense, [batch_size, max_sent_size, num_senses])
                logits = tf.multiply(logits_org, hierarchy)
                predictions.append(tf.argmax(logits, 2))

            float_sense_mask = tf.cast(sense_mask[gpu_idx], 'float')

            loss = tf.contrib.seq2seq.sequence_loss(logits, y[gpu_idx], float_sense_mask, name="loss")
            l2_loss = l2_lambda * tf.losses.get_regularization_loss()

            total_loss = tf.cond(pretrain, lambda:loss_pos, lambda:loss + loss_pos + l2_loss)

            summaries.append(tf.summary.scalar("loss_{}".format(gpu_idx), loss))
            summaries.append(tf.summary.scalar("loss_pos_{}".format(gpu_idx), loss_pos))
            summaries.append(tf.summary.scalar("total_loss_{}".format(gpu_idx), total_loss))

            optimizer = tf.train.AdamOptimizer(learning_rate)
            grads_vars = optimizer.compute_gradients(total_loss)

            clipped_grads = grads_vars
            if(clipping == True):
                clipped_grads = [(tf.clip_by_norm(grad, clip_norm), var) for grad, var in clipped_grads]

            tower_grads.append(clipped_grads)
            losses.append(total_loss)

with tf.device('/gpu:0'):
    tower_grads = average_gradients(tower_grads)
    losses = tf.add_n(losses)/len(losses)
    apply_grad_op = optimizer.apply_gradients(tower_grads, global_step=global_step)
    summaries.append(tf.summary.scalar('total_loss', losses))
    summaries.append(tf.summary.scalar('learning_rate', learning_rate))

    variable_averages = tf.train.ExponentialMovingAverage(moving_avg_deacy, global_step)
    variables_averages_op = variable_averages.apply(tf.trainable_variables())

    train_op = tf.group(apply_grad_op, variables_averages_op)
    saver = tf.train.Saver(tf.global_variables())
    summary = tf.summary.merge(summaries)

# %%
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="2,3"
# print (device_lib.list_local_devices())
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
config.allow_soft_placement = True
sess = tf.Session(config=config)
sess.run(tf.global_variables_initializer())                          # For initializing all the variables
summary_writer = tf.summary.FileWriter(log_dir, sess.graph)          # For writing Summaries

# %%
save_period = 100
log_period = 100

def model(xx, yy, yy_pos, mask, smask, train_cond=True, pretrain_cond=False):
    num_batches = int(len(xx)/(batch_size*num_gpus))
    _losses = 0
    temp_loss = 0
    preds_sense = []
    true_sense = []
    preds_pos = []
    true_pos = []
    
    for j in range(num_batches): 
        
        s = j * batch_size * num_gpus
        e = (j+1) * batch_size * num_gpus
        xx_re = xx[s:e].reshape([num_gpus, batch_size, -1])
        yy_re = yy[s:e].reshape([num_gpus, batch_size, -1])
        yy_pos_re = yy_pos[s:e].reshape([num_gpus, batch_size, -1])
        mask_re = mask[s:e].reshape([num_gpus, batch_size, -1])
        smask_re = smask[s:e].reshape([num_gpus, batch_size, -1])
 
        feed_dict = {x:xx_re, y:yy_re, y_pos:yy_pos_re, x_mask:mask_re, sense_mask:smask_re, pretrain:pretrain_cond, is_train:train_cond, input_keep_prob:keep_prob, word_emb_mat:word_embedding}
        
        if(train_cond==True):
            _, _loss, step, _summary = sess.run([train_op, losses, global_step, summary], feed_dict)
            summary_writer.add_summary(_summary, step)
            
            temp_loss += _loss
            if((j+1)%log_period==0):
                print("Steps: {}".format(step), "Loss:{0:.4f}".format(temp_loss/log_period), ", Current Loss: {0:.4f}".format(_loss))
                temp_loss = 0
            if((j+1)%save_period==0):
                saver.save(sess, save_path=save_dir)                         
                
        else:
            _loss, pred, crf_logits, trans_params_ = sess.run([total_loss, predictions, predictions_pos, total_trans_params], feed_dict)
            
            for i in range(num_gpus):
                preds_sense.append(pred[i][smask_re[i]])
                true_sense.append(yy_re[i][smask_re[i]])
                true_pos.append(yy_pos_re[i][mask_re[i]])
                temp = []
                for k in range(batch_size):
                    logit_ = crf_logits[i][k][:sum(mask_re[i][k])] # keep only the valid steps
                    viterbi_seq, viterbi_score = tf.contrib.crf.viterbi_decode(logit_, trans_params_[i])
                    temp += viterbi_seq
                preds_pos.append(temp)

        _losses +=_loss

    if(train_cond==False): 
        sense_preds = []
        sense_true = []
        pos_preds = []
        pos_true = []
        
        for preds in preds_sense:
            for ps in preds:      
                sense_preds.append(ps)  
        for trues in true_sense:
            for ts in trues:
                sense_true.append(ts)
        
        for preds in preds_pos:
            for ps in preds:      
                pos_preds.append(ps)      
        for trues in true_pos:
            for ts in trues:
                pos_true.append(ts)
                
        return _losses/num_batches, sense_preds, sense_true, pos_preds, pos_true

    return _losses/num_batches, step

def eval_score(yy, pred, yy_pos, pred_pos):
    f1 = f1_score(yy, pred, average='macro')
    accu = accuracy_score(yy, pred)
    f1_pos = f1_score(yy_pos, pred_pos, average='macro')
    accu_pos = accuracy_score(yy_pos, pred_pos)
    return f1*100, accu*100, f1_pos*100, accu_pos*100

# %%
x_id_train = train_data['x']
mask_train = train_data['x_mask']
sense_mask_train = train_data['sense_mask']
y_train = train_data['y']
y_pos_train = train_data['pos']

x_id_val = val_data['x']
mask_val = val_data['x_mask']
sense_mask_val = val_data['sense_mask']
y_val = val_data['y']
y_pos_val = val_data['pos']

x_id_test = test_data['x']
mask_test = test_data['x_mask']
sense_mask_test = test_data['sense_mask']
y_test = test_data['y']
y_pos_test = test_data['pos']

# %%
def testing():
    start_time = time.time()
    val_loss, val_pred, val_true, val_pred_pos, val_true_pos = model(x_id_val, y_val, y_pos_val, mask_val, sense_mask_val, train_cond=False)        
    f1_, accu_, f1_pos_, accu_pos_ = eval_score(val_true, val_pred, val_true_pos, val_pred_pos)
    time_taken = time.time() - start_time
    print("Val: F1 Score:{0:.2f}".format(f1_), "Accuracy:{0:.2f}".format(accu_), " POS: F1 Score:{0:.2f}".format(f1_pos_), "Accuracy:{0:.2f}".format(accu_pos_), "Loss:{0:.4f}".format(val_loss), ", Time: {0:.1f}".format(time_taken))
    return f1_, accu_, f1_pos_, accu_pos_

def evaluate():
    start_time = time.time()
    test_loss1, test_pred1, test_true1, test_pred_pos1, test_true_pos1 = model(x_id_test, y_test, y_pos_test, mask_test, sense_mask_test, train_cond=False)        
    test_loss2, test_pred2, test_true2, test_pred_pos2, test_true_pos2 = model(x_id_test[-num_gpus*batch_size:], y_test[-num_gpus*batch_size:], y_pos_test[-num_gpus*batch_size:], mask_test[-num_gpus*batch_size:], sense_mask_test[-num_gpus*batch_size:], train_cond=False)        
    test_loss = test_loss1 + test_loss2
    test_true = test_true1 + test_true2
    test_pred = test_pred1 + test_pred2
    test_pred_pos = test_pred_pos1 + test_pred_pos2
    test_true_pos = test_true_pos1 + test_true_pos2
    f1_, accu_, f1_pos_, accu_pos_ = eval_score(test_true, test_pred, test_true_pos, test_pred_pos)
    time_taken = time.time() - start_time
    print("Test: F1 Score:{0:.2f}".format(f1_), "Accuracy:{0:.2f}".format(accu_), " POS: F1 Score:{0:.2f}".format(f1_pos_), "Accuracy:{0:.2f}".format(accu_pos_), "Loss:{0:.4f}".format(test_loss), ", Time: {0:.1f}".format(time_taken))
    return f1_, accu_, f1_pos_, accu_pos_

def training(current_epoch, pre_train_cond):
        random = np.random.choice(len(y_train), size=(len(y_train)), replace=False)
        x_id_train_tmp = x_id_train[random]
        y_train_tmp = y_train[random]
        mask_train_tmp = mask_train[random]    
        sense_mask_train_tmp = sense_mask_train[random]
        y_pos_train_tmp = y_pos_train[random]

        start_time = time.time()
        train_loss, step = model(x_id_train_tmp, y_train_tmp, y_pos_train_tmp, mask_train_tmp, sense_mask_train_tmp, pretrain_cond=pre_train_cond)
        time_taken = time.time() - start_time
        print("Epoch: {}".format(current_epoch+1),", Step: {}".format(step), ", loss: {0:.4f}".format(train_loss), ", Time: {0:.1f}".format(time_taken))
        saver.save(sess, save_path=save_dir)                         
        print("Model Saved")
        return [step, train_loss]

# %%
loss_collection = []
val_collection = []
num_epochs = 20
val_period = 2

# Pretraining POS Tags
training(0, True)
training(1, True)
testing()

for i in range(num_epochs):
    loss_collection.append(training(i, False))
    if((i+1)%val_period==0):
        val_collection.append(testing())
# Out:
# Steps: 100 Loss:2.7041 , Current Loss: 0.9663
# Steps: 200 Loss:0.5753 , Current Loss: 0.3636
# Steps: 300 Loss:0.2927 , Current Loss: 0.2445
# Steps: 400 Loss:0.2124 , Current Loss: 0.1738
# Steps: 500 Loss:0.1775 , Current Loss: 0.1713
# Steps: 600 Loss:0.1528 , Current Loss: 0.1422
# Steps: 700 Loss:0.1402 , Current Loss: 0.1354
# Steps: 800 Loss:0.1298 , Current Loss: 0.1223
# Epoch: 1 , Step: 885 , loss: 0.5071 , Time: 5541.4
# Model Saved
# Steps: 985 Loss:0.1141 , Current Loss: 0.1139
# Steps: 1085 Loss:0.1090 , Current Loss: 0.1062
# Steps: 1185 Loss:0.1054 , Current Loss: 0.1041
# Steps: 1285 Loss:0.1012 , Current Loss: 0.0977
# Steps: 1385 Loss:0.0985 , Current Loss: 0.0927
# Steps: 1485 Loss:0.0971 , Current Loss: 0.0983
# Steps: 1585 Loss:0.0942 , Current Loss: 0.0904
# Steps: 1685 Loss:0.0923 , Current Loss: 0.1011
# Epoch: 2 , Step: 1770 , loss: 0.1004 , Time: 5490.5
# Model Saved
# Val: F1 Score:1.58 Accuracy:2.71  POS: F1 Score:96.86 Accuracy:98.46 Loss:56.0402 , Time: 1224.2
# Steps: 1870 Loss:3.4899 , Current Loss: 2.5138
# Steps: 1970 Loss:2.3493 , Current Loss: 2.1967
# Steps: 2070 Loss:2.1355 , Current Loss: 1.9682
# Steps: 2170 Loss:1.9881 , Current Loss: 1.9825
# Steps: 2270 Loss:1.8748 , Current Loss: 1.8301
# Steps: 2370 Loss:1.7783 , Current Loss: 1.7569
# Steps: 2470 Loss:1.6926 , Current Loss: 1.6326
# Steps: 2570 Loss:1.6334 , Current Loss: 1.6201
# Epoch: 1 , Step: 2655 , loss: 2.0652 , Time: 5619.7
# Model Saved
# Steps: 2755 Loss:1.5170 , Current Loss: 1.5657
# Steps: 2855 Loss:1.4718 , Current Loss: 1.4305
# Steps: 2955 Loss:1.4264 , Current Loss: 1.4234
# Steps: 3055 Loss:1.4006 , Current Loss: 1.3754
# Steps: 3155 Loss:1.3756 , Current Loss: 1.3100
# Steps: 3255 Loss:1.3355 , Current Loss: 1.3913
# Steps: 3355 Loss:1.3209 , Current Loss: 1.3103
# Steps: 3455 Loss:1.2917 , Current Loss: 1.1801
# Epoch: 2 , Step: 3540 , loss: 1.3819 , Time: 5564.0
# Model Saved
# Val: F1 Score:51.71 Accuracy:67.05  POS: F1 Score:95.01 Accuracy:97.53 Loss:1.2816 , Time: 1221.5
# Steps: 3640 Loss:1.2247 , Current Loss: 1.2626
# Steps: 3740 Loss:1.2193 , Current Loss: 1.2129
# Steps: 3840 Loss:1.2162 , Current Loss: 1.2154
# Steps: 3940 Loss:1.1871 , Current Loss: 1.1357
# Steps: 4040 Loss:1.1775 , Current Loss: 1.1826
# Steps: 4140 Loss:1.1694 , Current Loss: 1.2317
# Steps: 4240 Loss:1.1557 , Current Loss: 1.1885
# Steps: 4340 Loss:1.1496 , Current Loss: 1.0398
# Epoch: 3 , Step: 4425 , loss: 1.1834 , Time: 5599.9
# Model Saved
# Steps: 4525 Loss:1.1021 , Current Loss: 1.1471
# Steps: 4625 Loss:1.0868 , Current Loss: 1.0218
# Steps: 4725 Loss:1.0843 , Current Loss: 0.9819
# Steps: 4825 Loss:1.0912 , Current Loss: 1.0575
# Steps: 4925 Loss:1.0781 , Current Loss: 1.0942
# Steps: 5025 Loss:1.0658 , Current Loss: 1.0933
# Steps: 5125 Loss:1.0761 , Current Loss: 1.1526
# Steps: 5225 Loss:1.0744 , Current Loss: 1.1019
# Epoch: 4 , Step: 5310 , loss: 1.0805 , Time: 5547.8
# Model Saved
# /users/btech/aviraj/envs/lib/python3.5/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Val: F1 Score:60.56 Accuracy:72.64  POS: F1 Score:95.28 Accuracy:97.66 Loss:1.0883 , Time: 1219.8
# Steps: 5410 Loss:1.0292 , Current Loss: 0.9855
# Steps: 5510 Loss:1.0266 , Current Loss: 0.9340
# Steps: 5610 Loss:1.0197 , Current Loss: 0.9833
# Steps: 5710 Loss:1.0263 , Current Loss: 1.0224
# Steps: 5810 Loss:1.0208 , Current Loss: 1.0309
# Steps: 5910 Loss:1.0134 , Current Loss: 1.0244
# Steps: 6010 Loss:1.0087 , Current Loss: 0.9935
# Steps: 6110 Loss:1.0133 , Current Loss: 0.9885
# Epoch: 5 , Step: 6195 , loss: 1.0191 , Time: 5598.4
# Model Saved
# Steps: 6295 Loss:0.9759 , Current Loss: 0.9781
# Steps: 6395 Loss:0.9829 , Current Loss: 1.0025
# Steps: 6495 Loss:0.9816 , Current Loss: 0.9933
# Steps: 6595 Loss:0.9700 , Current Loss: 1.0019
# Steps: 6695 Loss:0.9767 , Current Loss: 1.0140
# Steps: 6795 Loss:0.9733 , Current Loss: 0.9803
# Steps: 6895 Loss:0.9738 , Current Loss: 1.0031
# Steps: 6995 Loss:0.9616 , Current Loss: 0.8713
# Epoch: 6 , Step: 7080 , loss: 0.9739 , Time: 5550.9
# Model Saved
# Val: F1 Score:65.28 Accuracy:74.83  POS: F1 Score:95.59 Accuracy:97.82 Loss:1.0015 , Time: 1226.8
# Steps: 7180 Loss:0.9348 , Current Loss: 0.9645
# Steps: 7280 Loss:0.9353 , Current Loss: 0.8544
# Steps: 7380 Loss:0.9333 , Current Loss: 0.9297
# Steps: 7480 Loss:0.9367 , Current Loss: 0.9605
# Steps: 7580 Loss:0.9513 , Current Loss: 0.8921
# Steps: 7680 Loss:0.9447 , Current Loss: 1.0125
# Steps: 7780 Loss:0.9413 , Current Loss: 0.9272
# Steps: 7880 Loss:0.9418 , Current Loss: 0.9387
# Epoch: 7 , Step: 7965 , loss: 0.9402 , Time: 5604.0
# Model Saved
# Steps: 8065 Loss:0.9089 , Current Loss: 0.8382
# Steps: 8165 Loss:0.9088 , Current Loss: 0.8546
# Steps: 8265 Loss:0.9160 , Current Loss: 0.9159
# Steps: 8365 Loss:0.9238 , Current Loss: 0.9412
# Steps: 8465 Loss:0.9130 , Current Loss: 0.9509
# Steps: 8565 Loss:0.9200 , Current Loss: 0.8821
# Steps: 8665 Loss:0.9104 , Current Loss: 0.9745
# Steps: 8765 Loss:0.9189 , Current Loss: 0.9409
# Epoch: 8 , Step: 8850 , loss: 0.9145 , Time: 5545.6
# Model Saved
# Val: F1 Score:66.67 Accuracy:75.76  POS: F1 Score:95.65 Accuracy:97.84 Loss:0.9672 , Time: 1221.5
# Steps: 8950 Loss:0.8807 , Current Loss: 0.9344
# Steps: 9050 Loss:0.8857 , Current Loss: 0.9490
# Steps: 9150 Loss:0.8880 , Current Loss: 0.8813
# Steps: 9250 Loss:0.8890 , Current Loss: 0.9292
# Steps: 9350 Loss:0.8970 , Current Loss: 0.8783

# %%
loss_collection = []
val_collection = []
num_epochs = 20
val_period = 2

for i in range(num_epochs):
    loss_collection.append(training(i, False))
    if((i+1)%val_period==0):
        val_collection.append(testing())
# Out:
# Steps: 9650 Loss:0.8659 , Current Loss: 0.7974
# Steps: 9750 Loss:0.8728 , Current Loss: 0.8606
# Steps: 9850 Loss:0.8813 , Current Loss: 0.8411
# Steps: 9950 Loss:0.8808 , Current Loss: 0.8811
# Steps: 10050 Loss:0.8844 , Current Loss: 0.8150
# Steps: 10150 Loss:0.8917 , Current Loss: 0.9244
# Steps: 10250 Loss:0.8872 , Current Loss: 0.8863
# Steps: 10350 Loss:0.8795 , Current Loss: 0.8402
# Epoch: 1 , Step: 10435 , loss: 0.8798 , Time: 5713.7
# Model Saved
# Steps: 10535 Loss:0.8541 , Current Loss: 0.8294
# Steps: 10635 Loss:0.8574 , Current Loss: 0.8407
# Steps: 10735 Loss:0.8591 , Current Loss: 0.7883
# Steps: 10835 Loss:0.8667 , Current Loss: 0.8372
# Steps: 10935 Loss:0.8674 , Current Loss: 0.8305
# Steps: 11035 Loss:0.8619 , Current Loss: 0.8683
# Steps: 11135 Loss:0.8661 , Current Loss: 0.8426
# Steps: 11235 Loss:0.8631 , Current Loss: 0.9462
# Epoch: 2 , Step: 11320 , loss: 0.8632 , Time: 6225.4
# Model Saved

# %%
testing()
# Out:
# Val: F1 Score:69.30 Accuracy:76.77  POS: F1 Score:95.84 Accuracy:97.95 Loss:0.9300 , Time: 1255.1
# (69.2962611581028, 76.77300570052756, 95.84071758883296, 97.9463922660675)

# %%
loss_collection = []
val_collection = []
num_epochs = 20
val_period = 2

for i in range(num_epochs):
    loss_collection.append(training(i, False))
    if((i+1)%val_period==0):
        val_collection.append(testing())
# Out:
# Steps: 11420 Loss:0.8337 , Current Loss: 0.8852
# Steps: 11520 Loss:0.8446 , Current Loss: 0.8738
# Steps: 11620 Loss:0.8524 , Current Loss: 0.8942
# Steps: 11720 Loss:0.8534 , Current Loss: 0.7778
# Steps: 11820 Loss:0.8547 , Current Loss: 0.8494
# Steps: 11920 Loss:0.8577 , Current Loss: 0.8834
# Steps: 12020 Loss:0.8476 , Current Loss: 0.9306
# Steps: 12120 Loss:0.8477 , Current Loss: 0.8267
# Epoch: 1 , Step: 12205 , loss: 0.8496 , Time: 5356.1
# Model Saved
# Steps: 12305 Loss:0.8293 , Current Loss: 0.8810
# Steps: 12405 Loss:0.8273 , Current Loss: 0.8050
# Steps: 12505 Loss:0.8373 , Current Loss: 0.8589
# Steps: 12605 Loss:0.8317 , Current Loss: 0.9251
# Steps: 12705 Loss:0.8369 , Current Loss: 0.7794
# Steps: 12805 Loss:0.8411 , Current Loss: 0.8712
# Steps: 12905 Loss:0.8374 , Current Loss: 0.8763
# Steps: 13005 Loss:0.8431 , Current Loss: 0.8095
# Epoch: 2 , Step: 13090 , loss: 0.8364 , Time: 6923.9
# Model Saved
# Val: F1 Score:69.66 Accuracy:76.99  POS: F1 Score:95.88 Accuracy:97.97 Loss:0.9195 , Time: 1829.5
# Steps: 13190 Loss:0.8078 , Current Loss: 0.9049
# Steps: 13290 Loss:0.8129 , Current Loss: 0.8126
# Steps: 13390 Loss:0.8259 , Current Loss: 0.8482
# Steps: 13490 Loss:0.8332 , Current Loss: 0.9451
# Steps: 13590 Loss:0.8270 , Current Loss: 0.7518
# Steps: 13690 Loss:0.8297 , Current Loss: 0.8113
# Steps: 13790 Loss:0.8258 , Current Loss: 0.8035
# Steps: 13890 Loss:0.8344 , Current Loss: 0.8233
# Epoch: 3 , Step: 13975 , loss: 0.8252 , Time: 6848.7
# Model Saved
# Steps: 14075 Loss:0.8063 , Current Loss: 0.8162
# Steps: 14175 Loss:0.8106 , Current Loss: 0.8546
# Steps: 14275 Loss:0.8108 , Current Loss: 0.9083
# Steps: 14375 Loss:0.8114 , Current Loss: 0.8243
# Steps: 14475 Loss:0.8189 , Current Loss: 0.7611
# Steps: 14575 Loss:0.8174 , Current Loss: 0.8890
# Steps: 14675 Loss:0.8159 , Current Loss: 0.8067
# Steps: 14775 Loss:0.8189 , Current Loss: 0.8186
# Epoch: 4 , Step: 14860 , loss: 0.8150 , Time: 5204.3
# Model Saved
# Val: F1 Score:70.51 Accuracy:77.31  POS: F1 Score:95.98 Accuracy:97.99 Loss:0.9011 , Time: 1167.8
# Steps: 14960 Loss:0.7972 , Current Loss: 0.8350
# Steps: 15060 Loss:0.7942 , Current Loss: 0.8735
# Steps: 15160 Loss:0.8002 , Current Loss: 0.8143
# Steps: 15260 Loss:0.8050 , Current Loss: 0.7675
# Steps: 15360 Loss:0.8097 , Current Loss: 0.7184
# Steps: 15460 Loss:0.8096 , Current Loss: 0.7899
# Steps: 15560 Loss:0.8091 , Current Loss: 0.7653
# Steps: 15660 Loss:0.8080 , Current Loss: 0.7749
# Epoch: 5 , Step: 15745 , loss: 0.8049 , Time: 5288.7
# Model Saved
# Steps: 15845 Loss:0.7853 , Current Loss: 0.7313
# Steps: 15945 Loss:0.7887 , Current Loss: 0.7778
# Steps: 16045 Loss:0.7901 , Current Loss: 0.7851
# Steps: 16145 Loss:0.7998 , Current Loss: 0.7774
# Steps: 16245 Loss:0.8001 , Current Loss: 0.7567
# Steps: 16345 Loss:0.8027 , Current Loss: 0.8170
# Steps: 16445 Loss:0.8097 , Current Loss: 0.8434
# Steps: 16545 Loss:0.7947 , Current Loss: 0.7656
# Epoch: 6 , Step: 16630 , loss: 0.7974 , Time: 5244.6
# Model Saved
# Val: F1 Score:71.12 Accuracy:77.76  POS: F1 Score:96.06 Accuracy:98.03 Loss:0.8762 , Time: 1172.3
# Steps: 16730 Loss:0.7780 , Current Loss: 0.7547
# Steps: 16830 Loss:0.7793 , Current Loss: 0.7853
# Steps: 16930 Loss:0.7893 , Current Loss: 0.8775
# Steps: 17030 Loss:0.7799 , Current Loss: 0.6567
# Steps: 17130 Loss:0.7983 , Current Loss: 0.7741
# Steps: 17230 Loss:0.7927 , Current Loss: 0.7261
# Steps: 17330 Loss:0.7904 , Current Loss: 0.8271
# Steps: 17430 Loss:0.7975 , Current Loss: 0.7801
# Epoch: 7 , Step: 17515 , loss: 0.7887 , Time: 5236.4
# Model Saved
# Steps: 17615 Loss:0.7793 , Current Loss: 0.8047
# Steps: 17715 Loss:0.7703 , Current Loss: 0.7198
# Steps: 17815 Loss:0.7753 , Current Loss: 0.7553
# Steps: 17915 Loss:0.7874 , Current Loss: 0.7835
# Steps: 18015 Loss:0.7783 , Current Loss: 0.8066
# Steps: 18115 Loss:0.7777 , Current Loss: 0.7801
# Steps: 18215 Loss:0.7884 , Current Loss: 0.8425
# Steps: 18315 Loss:0.7851 , Current Loss: 0.8354
# Epoch: 8 , Step: 18400 , loss: 0.7807 , Time: 5350.8
# Model Saved
# Val: F1 Score:71.60 Accuracy:77.99  POS: F1 Score:95.89 Accuracy:98.05 Loss:0.8706 , Time: 1169.0
# Steps: 18500 Loss:0.7670 , Current Loss: 0.8459
# Steps: 18600 Loss:0.7664 , Current Loss: 0.7630
# Steps: 18700 Loss:0.7688 , Current Loss: 0.7700
# Steps: 18800 Loss:0.7762 , Current Loss: 0.6794
# Steps: 18900 Loss:0.7687 , Current Loss: 0.8296
# Steps: 19000 Loss:0.7766 , Current Loss: 0.7924
# Steps: 19100 Loss:0.7856 , Current Loss: 0.8390
# Steps: 19200 Loss:0.7849 , Current Loss: 0.8761
# Epoch: 9 , Step: 19285 , loss: 0.7747 , Time: 5597.4
# Model Saved
# Steps: 19385 Loss:0.7483 , Current Loss: 0.7149
# Steps: 19485 Loss:0.7721 , Current Loss: 0.8098
# Steps: 19585 Loss:0.7564 , Current Loss: 0.7567
# Steps: 19685 Loss:0.7653 , Current Loss: 0.7632
# Steps: 19785 Loss:0.7692 , Current Loss: 0.7941
# Steps: 19885 Loss:0.7649 , Current Loss: 0.7084
# Steps: 19985 Loss:0.7694 , Current Loss: 0.7927
# Steps: 20085 Loss:0.7785 , Current Loss: 0.7749
# Epoch: 10 , Step: 20170 , loss: 0.7673 , Time: 5305.9
# Model Saved
# Val: F1 Score:72.08 Accuracy:78.23  POS: F1 Score:96.06 Accuracy:98.07 Loss:0.8756 , Time: 1157.8
# Steps: 20270 Loss:0.7596 , Current Loss: 0.6785
# Steps: 20370 Loss:0.7487 , Current Loss: 0.7379
# Steps: 20470 Loss:0.7484 , Current Loss: 0.7538
# Steps: 20570 Loss:0.7591 , Current Loss: 0.7370
# Steps: 20670 Loss:0.7615 , Current Loss: 0.8089
# Steps: 20770 Loss:0.7657 , Current Loss: 0.7886
# Steps: 20870 Loss:0.7702 , Current Loss: 0.7507
# Steps: 20970 Loss:0.7624 , Current Loss: 0.7902
# Epoch: 11 , Step: 21055 , loss: 0.7607 , Time: 5216.5
# Model Saved
# Steps: 21155 Loss:0.7470 , Current Loss: 0.7743
# Steps: 21255 Loss:0.7554 , Current Loss: 0.7269
# Steps: 21355 Loss:0.7549 , Current Loss: 0.7677
# Steps: 21455 Loss:0.7546 , Current Loss: 0.7290
# Steps: 21555 Loss:0.7573 , Current Loss: 0.7315
# Steps: 21655 Loss:0.7574 , Current Loss: 0.7176
# Steps: 21755 Loss:0.7570 , Current Loss: 0.6911
# Steps: 21855 Loss:0.7573 , Current Loss: 0.8103
# Epoch: 12 , Step: 21940 , loss: 0.7556 , Time: 5279.5
# Model Saved
# Val: F1 Score:72.12 Accuracy:78.21  POS: F1 Score:96.14 Accuracy:98.09 Loss:0.8485 , Time: 1162.1
# Steps: 22040 Loss:0.7437 , Current Loss: 0.7488
# Steps: 22140 Loss:0.7432 , Current Loss: 0.6244
# Steps: 22240 Loss:0.7407 , Current Loss: 0.6916
# Steps: 22340 Loss:0.7423 , Current Loss: 0.7646
# Steps: 22440 Loss:0.7487 , Current Loss: 0.7320
# Steps: 22540 Loss:0.7664 , Current Loss: 0.8103
# Steps: 22640 Loss:0.7550 , Current Loss: 0.8107
# Steps: 22740 Loss:0.7483 , Current Loss: 0.7590
# Epoch: 13 , Step: 22825 , loss: 0.7504 , Time: 5197.6
# Model Saved
# Steps: 22925 Loss:0.7356 , Current Loss: 0.6702
# Steps: 23025 Loss:0.7344 , Current Loss: 0.7600
# Steps: 23125 Loss:0.7481 , Current Loss: 0.7219
# Steps: 23225 Loss:0.7458 , Current Loss: 0.7731
# Steps: 23325 Loss:0.7383 , Current Loss: 0.7226
# Steps: 23425 Loss:0.7408 , Current Loss: 0.7247
# Steps: 23525 Loss:0.7535 , Current Loss: 0.6983
# Steps: 23625 Loss:0.7481 , Current Loss: 0.7690
# Epoch: 14 , Step: 23710 , loss: 0.7434 , Time: 5149.0
# Model Saved
# Val: F1 Score:72.53 Accuracy:78.49  POS: F1 Score:96.12 Accuracy:98.10 Loss:0.8624 , Time: 1156.2
# Steps: 23810 Loss:0.7273 , Current Loss: 0.7128
# Steps: 23910 Loss:0.7285 , Current Loss: 0.7102
# Steps: 24010 Loss:0.7336 , Current Loss: 0.7933
# Steps: 24110 Loss:0.7377 , Current Loss: 0.7278
# Steps: 24210 Loss:0.7423 , Current Loss: 0.7342
# Steps: 24310 Loss:0.7362 , Current Loss: 0.7964
# Steps: 24410 Loss:0.7492 , Current Loss: 0.7730
# Steps: 24510 Loss:0.7428 , Current Loss: 0.7058
# Epoch: 15 , Step: 24595 , loss: 0.7383 , Time: 5137.4
# Model Saved
# Steps: 24695 Loss:0.7187 , Current Loss: 0.6770
# Steps: 24795 Loss:0.7271 , Current Loss: 0.7440
# Steps: 24895 Loss:0.7245 , Current Loss: 0.7071
# Steps: 24995 Loss:0.7285 , Current Loss: 0.7352
# Steps: 25095 Loss:0.7404 , Current Loss: 0.7505
# Steps: 25195 Loss:0.7345 , Current Loss: 0.7511
# Steps: 25295 Loss:0.7408 , Current Loss: 0.7540
# Steps: 25395 Loss:0.7411 , Current Loss: 0.6927
# Epoch: 16 , Step: 25480 , loss: 0.7326 , Time: 5141.1
# Model Saved
# Val: F1 Score:72.38 Accuracy:78.50  POS: F1 Score:96.20 Accuracy:98.12 Loss:0.8492 , Time: 1167.7
# Steps: 25580 Loss:0.7168 , Current Loss: 0.6142
# Steps: 25680 Loss:0.7189 , Current Loss: 0.6639
# Steps: 25780 Loss:0.7302 , Current Loss: 0.7673
# Steps: 25880 Loss:0.7295 , Current Loss: 0.7911
# Steps: 25980 Loss:0.7285 , Current Loss: 0.7228
# Steps: 26080 Loss:0.7349 , Current Loss: 0.6603
# Steps: 26180 Loss:0.7325 , Current Loss: 0.7934
# Steps: 26280 Loss:0.7320 , Current Loss: 0.7338
# Epoch: 17 , Step: 26365 , loss: 0.7284 , Time: 5293.4
# Model Saved
# Steps: 26465 Loss:0.7054 , Current Loss: 0.6533
# Steps: 26565 Loss:0.7144 , Current Loss: 0.6982
# Steps: 26665 Loss:0.7196 , Current Loss: 0.7348
# Steps: 26765 Loss:0.7204 , Current Loss: 0.8101
# Steps: 26865 Loss:0.7306 , Current Loss: 0.6736
# Steps: 26965 Loss:0.7294 , Current Loss: 0.7457
# Steps: 27065 Loss:0.7314 , Current Loss: 0.6995
# Steps: 27165 Loss:0.7323 , Current Loss: 0.7011
# Epoch: 18 , Step: 27250 , loss: 0.7242 , Time: 5231.8
# Model Saved
# Val: F1 Score:73.08 Accuracy:78.78  POS: F1 Score:96.22 Accuracy:98.14 Loss:0.8385 , Time: 1165.1
# Steps: 27350 Loss:0.7040 , Current Loss: 0.7370
# Steps: 27450 Loss:0.7087 , Current Loss: 0.6505
# Steps: 27550 Loss:0.7152 , Current Loss: 0.7500
# Steps: 27650 Loss:0.7230 , Current Loss: 0.7523
# Steps: 27750 Loss:0.7200 , Current Loss: 0.7363
# Steps: 27850 Loss:0.7311 , Current Loss: 0.7387
# Steps: 27950 Loss:0.7190 , Current Loss: 0.7364
# Steps: 28050 Loss:0.7247 , Current Loss: 0.6989
# Epoch: 19 , Step: 28135 , loss: 0.7188 , Time: 5224.1
# Model Saved
# Steps: 28235 Loss:0.7063 , Current Loss: 0.6780
# Steps: 28335 Loss:0.7032 , Current Loss: 0.7242
# Steps: 28435 Loss:0.7117 , Current Loss: 0.7140
# Steps: 28535 Loss:0.7034 , Current Loss: 0.7557
# Steps: 28635 Loss:0.7215 , Current Loss: 0.7222
# Steps: 28735 Loss:0.7227 , Current Loss: 0.7134
# Steps: 28835 Loss:0.7232 , Current Loss: 0.7252
# Steps: 28935 Loss:0.7256 , Current Loss: 0.6915
# Epoch: 20 , Step: 29020 , loss: 0.7145 , Time: 5201.6
# Model Saved
# Val: F1 Score:73.64 Accuracy:78.96  POS: F1 Score:96.27 Accuracy:98.16 Loss:0.8267 , Time: 1168.2

# %%
loss_collection = []
val_collection = []
num_epochs = 20
val_period = 2

for i in range(num_epochs):
    loss_collection.append(training(i, False))
    if((i+1)%val_period==0):
        val_collection.append(testing())
# Out:
# Steps: 29120 Loss:0.7014 , Current Loss: 0.6778
# Steps: 29220 Loss:0.6984 , Current Loss: 0.7602
# Steps: 29320 Loss:0.7044 , Current Loss: 0.7146
# Steps: 29420 Loss:0.7057 , Current Loss: 0.6710
# Steps: 29520 Loss:0.7024 , Current Loss: 0.7128
# Steps: 29620 Loss:0.7128 , Current Loss: 0.7624
# Steps: 29720 Loss:0.7216 , Current Loss: 0.7092
# Steps: 29820 Loss:0.7199 , Current Loss: 0.7736
# Epoch: 1 , Step: 29905 , loss: 0.7099 , Time: 5776.5
# Model Saved
# Steps: 30005 Loss:0.6987 , Current Loss: 0.6664
# Steps: 30105 Loss:0.7031 , Current Loss: 0.7548
# Steps: 30205 Loss:0.6982 , Current Loss: 0.6986
# Steps: 30305 Loss:0.7060 , Current Loss: 0.7422
# Steps: 30405 Loss:0.7119 , Current Loss: 0.6347
# Steps: 30505 Loss:0.7103 , Current Loss: 0.7219
# Steps: 30605 Loss:0.7074 , Current Loss: 0.6640
# Steps: 30705 Loss:0.7136 , Current Loss: 0.6387
# Epoch: 2 , Step: 30790 , loss: 0.7074 , Time: 10020.4
# Model Saved
# Val: F1 Score:73.44 Accuracy:79.04  POS: F1 Score:96.25 Accuracy:98.15 Loss:0.8317 , Time: 1215.4
# Steps: 30890 Loss:0.6972 , Current Loss: 0.6650
# Steps: 30990 Loss:0.6896 , Current Loss: 0.5949
# Steps: 31090 Loss:0.7070 , Current Loss: 0.7707
# Steps: 31190 Loss:0.6941 , Current Loss: 0.6273
# Steps: 31290 Loss:0.7109 , Current Loss: 0.7062
# Steps: 31390 Loss:0.7073 , Current Loss: 0.7556
# Steps: 31490 Loss:0.7103 , Current Loss: 0.7204
# Steps: 31590 Loss:0.7115 , Current Loss: 0.6743
# Epoch: 3 , Step: 31675 , loss: 0.7031 , Time: 8308.3
# Model Saved
# Steps: 31775 Loss:0.6880 , Current Loss: 0.6490
# Steps: 31875 Loss:0.6838 , Current Loss: 0.7437
# Steps: 31975 Loss:0.6903 , Current Loss: 0.7194
# Steps: 32075 Loss:0.7085 , Current Loss: 0.7131
# Steps: 32175 Loss:0.6993 , Current Loss: 0.6381
# Steps: 32275 Loss:0.7061 , Current Loss: 0.7006
# Steps: 32375 Loss:0.7090 , Current Loss: 0.7145
# Steps: 32475 Loss:0.7014 , Current Loss: 0.6972
# Epoch: 4 , Step: 32560 , loss: 0.6992 , Time: 10225.2
# Model Saved
# Val: F1 Score:73.39 Accuracy:78.99  POS: F1 Score:96.26 Accuracy:98.18 Loss:0.8324 , Time: 1188.1
# Steps: 32660 Loss:0.6874 , Current Loss: 0.7029
# Steps: 32760 Loss:0.6938 , Current Loss: 0.6847
# Steps: 32860 Loss:0.6902 , Current Loss: 0.7070
# Steps: 32960 Loss:0.6889 , Current Loss: 0.7469
# Steps: 33060 Loss:0.6955 , Current Loss: 0.6503
# Steps: 33160 Loss:0.6934 , Current Loss: 0.6588
# Steps: 33260 Loss:0.6957 , Current Loss: 0.5862
# Steps: 33360 Loss:0.7130 , Current Loss: 0.7632
# Epoch: 5 , Step: 33445 , loss: 0.6963 , Time: 9928.1
# Model Saved
# Steps: 33545 Loss:0.6840 , Current Loss: 0.6699
# Steps: 33645 Loss:0.6856 , Current Loss: 0.6474
# Steps: 33745 Loss:0.6806 , Current Loss: 0.6405
# Steps: 33845 Loss:0.6914 , Current Loss: 0.6900
# Steps: 33945 Loss:0.6989 , Current Loss: 0.7245
# Steps: 34045 Loss:0.7000 , Current Loss: 0.8169
# Steps: 34145 Loss:0.6880 , Current Loss: 0.6875
# Steps: 34245 Loss:0.6971 , Current Loss: 0.7405
# Epoch: 6 , Step: 34330 , loss: 0.6921 , Time: 9578.3
# Model Saved
# Val: F1 Score:73.68 Accuracy:79.13  POS: F1 Score:96.25 Accuracy:98.17 Loss:0.8279 , Time: 1197.1
# Steps: 34430 Loss:0.6706 , Current Loss: 0.6837
# Steps: 34530 Loss:0.6788 , Current Loss: 0.6391
# Steps: 34630 Loss:0.6891 , Current Loss: 0.7324
# Steps: 34730 Loss:0.6981 , Current Loss: 0.6641
# Steps: 34830 Loss:0.6847 , Current Loss: 0.7570
# Steps: 34930 Loss:0.6945 , Current Loss: 0.7943
# Steps: 35030 Loss:0.6995 , Current Loss: 0.7126
# Steps: 35130 Loss:0.6889 , Current Loss: 0.6089
# Epoch: 7 , Step: 35215 , loss: 0.6883 , Time: 8732.6
# Model Saved
# Steps: 35315 Loss:0.6693 , Current Loss: 0.6794
# Steps: 35415 Loss:0.6827 , Current Loss: 0.7563
# Steps: 35515 Loss:0.6857 , Current Loss: 0.7160
# Steps: 35615 Loss:0.6809 , Current Loss: 0.6903
# Steps: 35715 Loss:0.6907 , Current Loss: 0.7630
# Steps: 35815 Loss:0.6866 , Current Loss: 0.7061
# Steps: 35915 Loss:0.6908 , Current Loss: 0.6652
# Steps: 36015 Loss:0.6893 , Current Loss: 0.6214
# Epoch: 8 , Step: 36100 , loss: 0.6849 , Time: 10415.9
# Model Saved
# Val: F1 Score:74.18 Accuracy:79.34  POS: F1 Score:96.32 Accuracy:98.19 Loss:0.8182 , Time: 1245.1
# Steps: 36200 Loss:0.6701 , Current Loss: 0.7107
# Steps: 36300 Loss:0.6765 , Current Loss: 0.5796

# %%
loss_collection = []
val_collection = []
num_epochs = 10
val_period = 2

for i in range(num_epochs):
    loss_collection.append(training(i, False))
    if((i+1)%val_period==0):
        val_collection.append(testing())
# Out:
# Steps: 36400 Loss:0.6760 , Current Loss: 0.6202
# Steps: 36500 Loss:0.6838 , Current Loss: 0.7253
# Steps: 36600 Loss:0.6768 , Current Loss: 0.6965
# Steps: 36700 Loss:0.6812 , Current Loss: 0.6789
# Steps: 36800 Loss:0.6838 , Current Loss: 0.7043
# Steps: 36900 Loss:0.6832 , Current Loss: 0.6470
# Steps: 37000 Loss:0.6876 , Current Loss: 0.7121
# Steps: 37100 Loss:0.6824 , Current Loss: 0.7287
# Epoch: 1 , Step: 37185 , loss: 0.6825 , Time: 9082.3
# Model Saved
# Steps: 37285 Loss:0.6732 , Current Loss: 0.7175
# Steps: 37385 Loss:0.6693 , Current Loss: 0.6925
# Steps: 37485 Loss:0.6734 , Current Loss: 0.6631
# Steps: 37585 Loss:0.6702 , Current Loss: 0.6722
# Steps: 37685 Loss:0.6747 , Current Loss: 0.6868
# Steps: 37785 Loss:0.6828 , Current Loss: 0.6931
# Steps: 37885 Loss:0.6735 , Current Loss: 0.5884
# Steps: 37985 Loss:0.6847 , Current Loss: 0.7059
# Epoch: 2 , Step: 38070 , loss: 0.6767 , Time: 9925.1
# Model Saved
# Val: F1 Score:74.04 Accuracy:79.38  POS: F1 Score:96.34 Accuracy:98.21 Loss:0.8093 , Time: 1240.6

# %%
evaluate()
# Out:
# Test: F1 Score:48.85 Accuracy:59.71  POS: F1 Score:88.35 Accuracy:95.86 Loss:4.0546 , Time: 11.6
# /users/btech/aviraj/envs/lib/python3.5/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# (48.84560447303337, 59.7051597051597, 88.3474369382831, 95.86436470322727)

# %%
start_time = time.time()
train_loss, train_pred, train_true, train_pred_pos, train_true_pos = model(x_id_train, y_train, y_pos_train, mask_train, sense_mask_train, train_cond=False)        
f1_, accu_, f1_pos_, accu_pos_ = etrain_score(train_true, train_pred, train_true_pos, train_pred_pos)
time_taken = time.time() - start_time
print("train: F1 Score:{0:.2f}".format(f1_), "Accuracy:{0:.2f}".format(accu_), " POS: F1 Score:{0:.2f}".format(f1_pos_), "Accuracy:{0:.2f}".format(accu_pos_), "Loss:{0:.4f}".format(train_loss), ", Time: {0:.1f}".format(time_taken))

# %%
saver.restore(sess, save_dir)
