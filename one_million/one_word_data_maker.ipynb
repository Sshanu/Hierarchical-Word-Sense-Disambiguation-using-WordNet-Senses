# %%
import pickle
from nltk.corpus import wordnet as wn

# %%
with open('/data/aviraj/dataset/raw_preprocess_train','rb') as f:
    global_data=pickle.load(f)

# %%
with open('/data/aviraj/dataset/semcor+omsti.gold.key.txt','r') as f:
    data_key=f.readlines()

# %%
def make_word_data(checkword):
    
    dataset_line=[]
    for i,list_ in enumerate(global_data): 
        ind=[idx for idx,it in enumerate(list_[3]) if it==checkword]
        for ii in ind:
            if list_[2][ii] is not None:
                dataset_line.append([list_[2][ii],list_[1],list_[4]])
    
    print(len(dataset_line))
    with open('/data/aviraj/dataset/checkwords/'+checkword + '_data', 'wb') as f:
        pickle.dump(dataset_line, f)
    with open('/data/aviraj/dataset/checkwords/'+checkword + '_data', 'rb') as f:
        data_ = pickle.load(f)

# %%
most_frequent_words=[('be', 17634),
 ('see', 7421),
 ('person', 7220),
 ('make', 6593),
 ('line', 5998),
 ('keep', 5616),
 ('give', 4228),
 ('return', 4175),
 ('work', 4020),
 ('follow', 3726)]

# %%
for word in most_frequent_words:
    make_word_data(word[0])

# %%
with open('../Glove/vocab_glove', 'rb') as f:
    vocab = pickle.load(f)

# %%
train_words = []
for sent in global_data:
    train_words.extend(sent[1])

# %%
len(train_words), len(set(train_words)), len(vocab)
# Out:
# (31243824, 189167, 400001)

# %%
import collections
unknown_words = []
for word in set(train_words):
    if word not in vocab:
        unknown_words.append(word)
        
un_counter = collections.Counter(unknown_words)
un_counter = dict(un_counter)

sorted_un_counter = sorted(un_counter.items(), key=lambda x:x[1], reverse=True)
sorted_un_counter
# Out:
# [('affordability.', 1),
#  ('a.11b.11', 1),
#  ('2/cp.3', 1),
#  ('cyberkids', 1),
#  ('1995-may', 1),
#  ('v/13', 1),
#  ('soros-kyrgyzstan', 1),
#  ('`e', 1),
#  ("d'organisations", 1),
#  ('child-health', 1),
#  ('230/2', 1),
#  ('financiable', 1),
#  ('e/1990/5/add.59', 1),
#  ('ferizaj/urosevac', 1),
#  ('paaet', 1),
#  ('torrid-mighty', 1),
#  ('a/c.1/56/l.33/rev.1', 1),
#  ('pikis', 1),
#  ('am2001/54/16', 1),
#  ('a/cn.9/331', 1),
#  ('understanding/judgment', 1),
#  ('energtica', 1),
#  ('bilten', 1),
#  ('elders/language', 1),
#  ('walkway/', 1),
#  ('fccc/cp/1996/2', 1),
#  ('o-m+', 1),
#  ('kong-registered', 1),
#  ('34-52', 1),
#  ('//epp.eurostat.ec.europa.eu/portal/page', 1),
#  ('5-alpha', 1),
#  ('26.', 1),
#  ('croakin', 1),
#  ('lvi-strauss', 1),
#  ('gavrilin', 1),
#  ('seriatim', 1),
#  ('formation.', 1),
#  ('production-networks', 1),
#  ('491.', 1),
#  ('brigot', 1),
#  ('60/125', 1),
#  ('33/115', 1),
#  ('5.2.2.2.1.6', 1),
#  ('a/c.5/54/52', 1),
#  ('jdcs', 1),
#  ('pre-maturity', 1),
#  ('36d', 1),
#  ('nationality-', 1),
#  ('non-highly', 1),
#  ('hygiene-related', 1),
#  ('backstitch', 1),
#  ('ohchr.53', 1),
#  ('eldon moritz', 1),
#  ('1994-1999.', 1),
#  ('a/63/219', 1),
#  ('msadieu', 1),
#  ('child care', 1),
#  ('abkhazia/tskhinvali', 1),
#  ('compatibility/convergence', 1),
#  ('imposable', 1),
#  ('tsallis', 1),
#  ('half-early', 1),
#  ('quasi-contract', 1),
#  ('somas', 1),
#  ('`legal', 1),
#  ('planned parenthood association', 1),
#  ('prior-consultation', 1),
#  ('circuits.', 1),
#  ('god.', 1),
#  ('fever-infected', 1),
#  ('s/2000/869', 1),
#  ('biophenyls', 1),
#  ('reimbursement.25', 1),
#  ('institute/p166', 1),
#  ('days.26', 1),
#  ('s/ac.26/1999/22', 1),
#  ('56/143', 1),
#  ('a/54/38/rev.1', 1),
#  ('cider-based', 1),
#  ('diffrence', 1),
#  ('cross-sectorally', 1),
#  ('verzijl', 1),
#  ('library-based', 1),
#  ('20/cp.8', 1),
#  ("l'ethnie", 1),
#  ('mamour', 1),
#  ('vii.13', 1),
#  ('a/c.5/62/l.47', 1),
#  ('fiscaliza', 1),
#  ('//warnewstoday.blogspot.com/', 1),
#  ('construed.', 1),
#  ('a/60/l.18', 1),
#  ('seetulsingh', 1),
#  ('unep/pops/cop.1/inf/12', 1),
#  ('36-power', 1),
#  ('sums up', 1),
#  ('265/57', 1),
#  ('cerd/c/365', 1),
#  ('prevalis', 1),
#  ('non-space-related', 1),
#  ('~135', 1),
#  ('2.9.79', 1),
#  ('islamiyah*', 1),
#  ('biotropic', 1),
#  ('7530', 1),
#  ('grade-a', 1),
#  ('8/1992', 1),
#  ('609.7', 1),
#  ('disrupted.', 1),
#  ('1968-1978', 1),
#  ('e/cn.4/2006/62', 1),
#  ('2008/09-2009/10', 1),
#  ('adasani', 1),
#  ('13200', 1),
#  ('ngosnon-governmental', 1),
#  ('ptf-r012/07', 1),
#  ('language-teaching', 1),
#  ('quasi-non-governmental', 1),
#  ('trans-israel', 1),
#  ('dedjo', 1),
#  ('w.a.t.', 1),
#  ('claims-development', 1),
#  ('5000466', 1),
#  ('soft-headed', 1),
#  ('youth-protection', 1),
#  ('superalloy', 1),
#  ('jason-1', 1),
#  ('a/58/65/add.1', 1),
#  ('staphanstsminda', 1),
#  ('falls out', 1),
#  ('hawaiian islands', 1),
#  ('campaa', 1),
#  ('stones.', 1),
#  ('dry.', 1),
#  ('under-elaborated', 1),
#  ('less-politicized', 1),
#  ('re-classifies', 1),
#  ('maimeskul', 1),
#  ('19075', 1),
#  ('a/61/850', 1),
#  ('complex.', 1),
#  ('ict4bus', 1),
#  ('search-and-rescue/aeromedical', 1),
#  ('inati', 1),
#  ('e/cn.7/2001/16', 1),
#  ('grahl-madsen', 1),
#  ('al-`uraybi', 1),
#  ('enlisted men', 1),
#  ('172000', 1),
#  ('58/6', 1),
#  ('sisei', 1),
#  ('www.rollenbilder.de', 1),
#  ('produceing', 1),
#  ('prokon', 1),
#  ('alsouf', 1),
#  ('sddh', 1),
#  ('kapok-filled', 1),
#  ('sleeping it off', 1),
#  ('run roughshod', 1),
#  ('chloroflorocarbons', 1),
#  ('u.s. department of the interior', 1),
#  ('properly.', 1),
#  ('/11', 1),
#  ('kriged', 1),
#  ('neodymium-doped', 1),
#  ('satrec', 1),
#  ('clauses*', 1),
#  ('a/59/728', 1),
#  ('a/cn.9/wg.iii/wp.29', 1),
#  ('electric circuit', 1),
#  ('institutions.23', 1),
#  ('country-to-city', 1),
#  ('676/1996', 1),
#  ('vimbi', 1),
#  ('school girls', 1),
#  ('boismassif', 1),
#  ('precipice.', 1),
#  ('maranho', 1),
#  ('glazer-fine', 1),
#  ('1999/11', 1),
#  ('1.139', 1),
#  ('`unreasonably', 1),
#  ('33-100', 1),
#  ('slow-spreading', 1),
#  ('judiciary.44', 1),
#  ('yancy-6', 1),
#  ('lodgment', 1),
#  ('muridi', 1),
#  ('khurnubiyah', 1),
#  ('gillibert', 1),
#  ('56/184', 1),
#  ('a.27a.4', 1),
#  ('qalubia', 1),
#  ('`legitimate', 1),
#  ('orasa', 1),
#  ('commander/deputy', 1),
#  ('visa-issuing', 1),
#  ('four-five', 1),
#  ('2006/49', 1),
#  ("chunke'er", 1),
#  ('srvux', 1),
#  ('gave out', 1),
#  ('fofor', 1),
#  ('296-341', 1),
#  ("k'eqchi", 1),
#  ('consulting firm', 1),
#  ('a/c.1/55/l.28/rev.1', 1),
#  ('non-kosovo', 1),
#  ('eleven.', 1),
#  ('9.a.9.', 1),
#  ('eb107.r8', 1),
#  ('stereo-types', 1),
#  ('danovaro', 1),
#  ('countries.5', 1),
#  ('ex-terrorists', 1),
#  ('carerscarer', 1),
#  ('withdrawn.', 1),
#  ('congo/kinshasa', 1),
#  ('use.34', 1),
#  ('now and then', 1),
#  ('incoordination', 1),
#  ('laikha', 1),
#  ('actors.16', 1),
#  ('field-level', 1),
#  ('53/85', 1),
#  ('ovia', 1),
#  ('6270/1998b', 1),
#  ('e/cn.3/2002/26', 1),
#  ('cedaw/c/arm/2', 1),
#  ('ankara-turkey', 1),
#  ('morieh', 1),
#  ('penny arcade', 1),
#  ('ploix', 1),
#  ('environmentcology', 1),
#  ('infopoverty', 1),
#  ('x=10-13', 1),
#  ('easy-to-operate', 1),
#  ('johnny keating', 1),
#  ('ribkona', 1),
#  ('unrifled', 1),
#  ('centrafricains', 1),
#  ('british guiana', 1),
#  ('criminal law', 1),
#  ('0886-3210', 1),
#  ('swedpower', 1),
#  ('`missing', 1),
#  ('slm/a-abdul', 1),
#  ('post-commission', 1),
#  ('dr-cafta', 1),
#  ('obligees', 1),
#  ('toxicologically', 1),
#  ('a/es-10/40-s/2000/1025', 1),
#  ('e/conf.95/6/ip.20', 1),
#  ('cedaw/c/pol/6', 1),
#  ('04/06/2003', 1),
#  ('goes for', 1),
#  ('corporal johnson', 1),
#  ('//mingorp.hr/default.asp', 1),
#  ('6.6.4', 1),
#  ('contractand', 1),
#  ('corings', 1),
#  ('grisby', 1),
#  ('cat/c/aut/co/3', 1),
#  ('income-related', 1),
#  ('digebi', 1),
#  ('fccc/kp/cmp/2005/misc.2', 1),
#  ('candidacy.', 1),
#  ('undt', 1),
#  ('myanmar-language', 1),
#  ('paternottre', 1),
#  ('s/2000/502', 1),
#  ('a/59/574-s/2004/909', 1),
#  ('father galtier', 1),
#  ('workforce.', 1),
#  ('14c-labelled', 1),
#  ('10/95', 1),
#  ('gender-biased', 1),
#  ('x-radiation', 1),
#  ('real estate brokers', 1),
#  ('fool-proof', 1),
#  ('inter-basin', 1),
#  ('//spacelink.nasa.gov', 1),
#  ('3.1.10', 1),
#  ('maysir', 1),
#  ('vioiln', 1),
#  ('late-ish', 1),
#  ('meff', 1),
#  ('mission.23', 1),
#  ('newsweek.', 1),
#  ('cross-government', 1),
#  ('pademba', 1),
#  ('double-strength', 1),
#  ('mcn.', 1),
#  ('eschauzier', 1),
#  ('iosn', 1),
#  ('a/58/518', 1),
#  ('253355000', 1),
#  ('a/63/379', 1),
#  ('2005/58', 1),
#  ('inghilabe', 1),
#  ('unitar/', 1),
#  ('samliv', 1),
#  ('re-adapting', 1),
#  ('sub-directorate', 1),
#  ('0102', 1),
#  ('eyelashes.', 1),
#  ('presidentsthat', 1),
#  ('038.', 1),
#  ('mercury.', 1),
#  ('problem-solvers', 1),
#  ('space-law', 1),
#  ('61/555', 1),
#  ('www.business-asia.net', 1),
#  ('and-a-half', 1),
#  ('a/50/713', 1),
#  ('dpma', 1),
#  ('ohchr-hired', 1),
#  ('workshop/seminar', 1),
#  ('lm11', 1),
#  ('cared for', 1),
#  ('278.9', 1),
#  ('wound tumor virus', 1),
#  ('55/13', 1),
#  ('re-specialization', 1),
#  ('takatu', 1),
#  ('science-intensive', 1),
#  ('esquadra', 1),
#  ('third reich', 1),
#  ('cepex', 1),
#  ('nanuli', 1),
#  ('folk lore', 1),
#  ('kent house', 1),
#  ('sir arthur conan doyle', 1),
#  ('sneaked off', 1),
#  ('l.7', 1),
#  ('punitiveness', 1),
#  ('//nordendivision.nfi.ku.dk', 1),
#  ('narem', 1),
#  ('nzdl', 1),
#  ('1998/23', 1),
#  ('hispanics.', 1),
#  ('`designated', 1),
#  ('10-centimetre', 1),
#  ('welfare.', 1),
#  ('home fashions league', 1),
#  ('garamone', 1),
#  ('fk506', 1),
#  ('36/93', 1),
#  ('senama', 1),
#  ('life-preserving', 1),
#  ('radio-labelled', 1),
#  ('gayety', 1),
#  ('636.9', 1),
#  ('textile/clothing', 1),
#  ('cosmos-954', 1),
#  ('lowest-paid', 1),
#  ('unhcr/minurso', 1),
#  ('59/166', 1),
#  ('s/2002/1146', 1),
#  ('add.2-3', 1),
#  ('54/19', 1),
#  ('non-wage-earners', 1),
#  ('s/2000/250', 1),
#  ('georgia/russia', 1),
#  ('`effects', 1),
#  ('new englander', 1),
#  ('chambershould', 1),
#  ('micro-macro', 1),
#  ('abandoned/unexploded', 1),
#  ('l986', 1),
#  ('conadi', 1),
#  ('nature-conservancy', 1),
#  ('4.1.1.5.1', 1),
#  ('cedaw/c/2009/i/1', 1),
#  ('s/24111', 1),
#  ('2001.5', 1),
#  ('e-government-as-a-whole', 1),
#  ('non-depository', 1),
#  ('fivims', 1),
#  ('zarm', 1),
#  ('`95', 1),
#  ('1990.21', 1),
#  ('john brown', 1),
#  ('grubi', 1),
#  ('a/c.4/56/3', 1),
#  ('come in', 1),
#  ('1974-1996', 1),
#  ('pre-conference', 1),
#  ('hewlett-woodmere', 1),
#  ('a/c.4/59/sr.10', 1),
#  ('ruquoy', 1),
#  ('s/1999/815', 1),
#  ('byer-rolnick', 1),
#  ('amc-12', 1),
#  ('egg plant', 1),
#  ('wetboek', 1),
#  ('simple-to-read', 1),
#  ('denationalizing', 1),
#  ('weapons*', 1),
#  ('demand-decreasing', 1),
#  ('chinked', 1),
#  ('219-221', 1),
#  ('a/s-27/3', 1),
#  ('farvardin', 1),
#  ('064', 1),
#  ('6/98', 1),
#  ('kampelman', 1),
#  ('charterists', 1),
#  ('cross-nationally', 1),
#  ('secretary general', 1),
#  ('shilpgrams.', 1),
#  ('al-shahamah', 1),
#  ('//library.iea.org/dbtw-wpd/textbase/papers/', 1),
#  ('rusamambo', 1),
#  ('e/cn.4/2000/10', 1),
#  ('corruption-related', 1),
#  ('process/procedure', 1),
#  ('a/cn.9/580/add.1', 1),
#  ('amates', 1),
#  ('a/hrc/6/l.24', 1),
#  ('managerial/', 1),
#  ('eca.', 1),
#  ('houch', 1),
#  ('speed limit', 1),
#  ('120-millimetre', 1),
#  ('el-hayr', 1),
#  ('yachtel', 1),
#  ('humenny', 1),
#  ('62/90', 1),
#  ('fifty-cent', 1),
#  ('free/libre', 1),
#  ('*56', 1),
#  ('admass', 1),
#  ('sit up', 1),
#  ('mail.', 1),
#  ('caucus/representation', 1),
#  ('gc.12/crp.3', 1),
#  ('chemical formula', 1),
#  ('kosovo-serb-majority', 1),
#  ('a/cn.9/wg.vi/wp.2/add.9', 1),
#  ('11-metre', 1),
#  ('teilzeit', 1),
#  ('/un-habitat/water', 1),
#  ('minascom', 1),
#  ('1948-1989', 1),
#  ('62-11', 1),
#  ('applied.22', 1),
#  ('s/2005/806', 1),
#  ('local-track', 1),
#  ('369.7', 1),
#  ('endowments.', 1),
#  ('gender-', 1),
#  ('oane', 1),
#  ('381-384', 1),
#  ('subcommittee.', 1),
#  ('inter-alia', 1),
#  ('unclarified', 1),
#  ('miyagi-ken', 1),
#  ('2003/80', 1),
#  ('chromspun', 1),
#  ('2000-596', 1),
#  ('201-203', 1),
#  ('227-239', 1),
#  ('permanent-member', 1),
#  ('591.70', 1),
#  ('prtend', 1),
#  ('transvestitism', 1),
#  ('ramilo', 1),
#  ('supply-based', 1),
#  ('regressiveness', 1),
#  ('corporate-sector', 1),
#  ('a-tall', 1),
#  ('emergency-driven', 1),
#  ('ultra-poor', 1),
#  ('khudr', 1),
#  ('20022006', 1),
#  ('/2004', 1),
#  ('idsn', 1),
#  ('cayman-based', 1),
#  ('ultra-luminous', 1),
#  ('balancing.', 1),
#  ('new yorkers', 1),
#  ('cosec', 1),
#  ('lpv', 1),
#  ('independentista', 1),
#  ('mweya', 1),
#  ('e/cn.4/2006/10', 1),
#  ('darrell royal', 1),
#  ('prevention/mitigation', 1),
#  ('assess.', 1),
#  ('bushaku', 1),
#  ('asatrade', 1),
#  ('larivire', 1),
#  ('frankie ricco', 1),
#  ('cross-conditionality', 1),
#  ('megaton bombs', 1),
#  ('airmalta', 1),
#  ('jack elliott', 1),
#  ('`one', 1),
#  ('medet', 1),
#  ('66/03', 1),
#  ('motels.', 1),
#  ('inter-force', 1),
#  ('to that extent', 1),
#  ('ortakligi', 1),
#  ('kulu-women', 1),
#  ('bands.', 1),
#  ('`reaching', 1),
#  ('threshold.', 1),
#  ('conflict.', 1),
#  ('isaas', 1),
#  ('budget/finance', 1),
#  ('non-detectability', 1),
#  ('.as', 1),
#  ('tertiary-level', 1),
#  ('hwc', 1),
#  ('1.2.7', 1),
#  ('alarming.', 1),
#  ('level.81', 1),
#  ('a/55/693-s/2000/1193', 1),
#  ('s/ac.40/sr.219', 1),
#  ('s/ac.26/1999/23', 1),
#  ('s/2001/874', 1),
#  ('quorum.', 1),
#  ('a/c.3/63/l.41', 1),
#  ('e/ac.51/2008/l.2', 1),
#  ('dug-wells', 1),
#  ('moniaga', 1),
#  ('claimant.', 1),
#  ('730.2', 1),
#  ('brempt', 1),
#  ('10/cp.13', 1),
#  ('final period', 1),
#  ('non-reciprocity', 1),
#  ('aviacin', 1),
#  ('transarctic-2000', 1),
#  ('question-marks', 1),
#  ('geohab', 1),
#  ('lifta', 1),
#  ('manufacture/produce', 1),
#  ('hunger.4', 1),
#  ('s/2000/392', 1),
#  ('2.b.5.g.', 1),
#  ('de-escalation', 1),
#  ('thunder-purple', 1),
#  ('incorporel', 1),
#  ('accreditation.', 1),
#  ('`generating', 1),
#  ('1998sf36', 1),
#  ('a/56/885', 1),
#  ('difficultiesalthough', 1),
#  ('einzelhandels', 1),
#  ('top-drawer', 1),
#  ('ccad', 1),
#  ("won't", 1),
#  ('2004b', 1),
#  ('s/2002/30/add.23', 1),
#  ('m124', 1),
#  ('inter alia', 1),
#  ('polyandrum', 1),
#  ('-terra', 1),
#  ('a/2157', 1),
#  ('6.5.2.1.1', 1),
#  ('tortureon', 1),
#  ('buldng', 1),
#  ('a/ac.109/2008/l.7', 1),
#  ('science-', 1),
#  ('developing-country', 1),
#  ('steering/coordinating', 1),
#  ('12/2003', 1),
#  ('al-rashidiyeh', 1),
#  ('fig trees', 1),
#  ('2010/mid-2010', 1),
#  ('a.b.a.o.', 1),
#  ('3c-qqt', 1),
#  ('tcnica', 1),
#  ('silver-painted', 1),
#  ('ouva', 1),
#  ('piling up', 1),
#  ('smmac', 1),
#  ('area/european', 1),
#  ('arigatou', 1),
#  ('e/cn.18/2003/11', 1),
#  ('sea-kaunlaran', 1),
#  ('y-list', 1),
#  ('notification/case', 1),
#  ('allegro con spirito', 1),
#  ('un-intentionally', 1),
#  ('overstraining', 1),
#  ('pdci-rda', 1),
#  ('louhanapessy', 1),
#  ('haematuria', 1),
#  ('re-appointed.', 1),
#  ('export-revenue', 1),
#  ('2003/212', 1),
#  ('neuro-scientific', 1),
#  ('lethal dose', 1),
#  ('rili', 1),
#  ('trained.', 1),
#  ('candle flame', 1),
#  ('appso', 1),
#  ("resources'.", 1),
#  ('monitoring/observation', 1),
#  ('biodiversity.28', 1),
#  ('funds/sponsors', 1),
#  ('non-adivasi', 1),
#  ('s/1999/981', 1),
#  ('sole-parent', 1),
#  ('paryin', 1),
#  ('2002/629/jha', 1),
#  ('8.a.1.b.', 1),
#  ('clear-sightedness', 1),
#  ('96/29/ec', 1),
#  ('re-zoning', 1),
#  ('godamit', 1),
#  ('projects.147', 1),
#  ('immortalization', 1),
#  ('viii.a', 1),
#  ("d'insertion", 1),
#  ('report13', 1),
#  ('hydrofluorocarbon-23', 1),
#  ('harvest-time', 1),
#  ('52/2', 1),
#  ('173-53', 1),
#  ('satty', 1),
#  ('recovery/business', 1),
#  ('al-`arab', 1),
#  ('out-posted', 1),
#  ('ukraine.', 1),
#  ('emop', 1),
#  ('caacchildren', 1),
#  ('yabed', 1),
#  ('middle western', 1),
#  ('hoscheit', 1),
#  ('takes the floor', 1),
#  ('nizin', 1),
#  ('7.427', 1),
#  ('katyr-yurt', 1),
#  ('baldone', 1),
#  ('armada-esma', 1),
#  ('mayi-mayi', 1),
#  ('mas-affiliated', 1),
#  ('calumniated', 1),
#  ('54/33', 1),
#  ('al-quds.', 1),
#  ('carmen-1', 1),
#  ('`janani', 1),
#  ('non-rostered', 1),
#  ('work-home', 1),
#  ('broker/facilitator', 1),
#  ('morf', 1),
#  ('wanla-weyn', 1),
#  ('lautem', 1),
#  ('settled down', 1),
#  ('fy2002', 1),
#  ('encountered.', 1),
#  ('fccc/sbi/2000/crp.11', 1),
#  ('river-men', 1),
#  ('architecture.1', 1),
#  ('1995b', 1),
#  ('thomas nelson page', 1),
#  ('operational.', 1),
#  ('november-17', 1),
#  ('mthodologie', 1),
#  ('s/2005/144', 1),
#  ('kabelwerke', 1),
#  ('alternative.', 1),
#  ('congolese-based', 1),
#  ('afub', 1),
#  ('a/57/97', 1),
#  ('systems.61', 1),
#  ('macedonia.', 1),
#  ('ghebremariam', 1),
#  ('a/cn.9/576', 1),
#  ('a/54/335', 1),
#  ('www.ilo.org/public/english/bureau/stat/guides/cpi/index.htm', 1),
#  ('navco', 1),
#  ('water buffaloes', 1),
#  ('mutoboba', 1),
#  ('1933.', 1),
#  ('khumri', 1),
#  ('odei', 1),
#  ('casino.', 1),
#  ('dhavan', 1),
#  ('pre-harvest', 1),
#  ('s/.107', 1),
#  ('indgenas', 1),
#  ('chammari', 1),
#  ('pilot.', 1),
#  ('50-cm', 1),
#  ('uluslararasi', 1),
#  ('54-55', 1),
#  ('all-european', 1),
#  ('uurban', 1),
#  ('hedda gabler', 1),
#  ('kimwenza', 1),
#  ('leasing-fuel', 1),
#  ('biodefence', 1),
#  ('australia-fiji', 1),
#  ('uncrd', 1),
#  ('stropped', 1),
#  ('a/hrc/4/5', 1),
#  ('microheterotrophs', 1),
#  ('civil-society', 1),
#  ('ganeson', 1),
#  ('destruction.27', 1),
#  ('isiley', 1),
#  ('a/ac.109/1999/l.13', 1),
#  ('57/107', 1),
#  ('soviet union', 1),
#  ('basabose', 1),
#  ('qubaysi', 1),
#  ('/21', 1),
#  ('regional/supranational', 1),
#  ('2004/9', 1),
#  ('ltas', 1),
#  ('a/c.5/55/23', 1),
#  ('fccc/sbsta/2005/misc.13', 1),
#  ('peacekeeping.2', 1),
#  ('non-approval', 1),
#  ('`extreme', 1),
#  ('2931', 1),
#  ('2005/264', 1),
#  ('ye-u', 1),
#  ('capeling-alakija', 1),
#  ('karaho', 1),
#  ('_schema=portal', 1),
#  ('unemployment-relief', 1),
#  ('e/cn.4/1999/49', 1),
#  ('day-clinics', 1),
#  ('education/liberian', 1),
#  ('secretary-general/high', 1),
#  ('israel-pna', 1),
#  ('neo-dadaist', 1),
#  ('cat/c/jpn/co/1', 1),
#  ('a/s-25/2', 1),
#  ('ngre', 1),
#  ('counter-performance', 1),
#  ('ouaddei', 1),
#  ('ccps2004', 1),
#  ('bsharre', 1),
#  ('al-salman', 1),
#  ('2003/82', 1),
#  ('non-replenishment', 1),
#  ('rights-inspired', 1),
#  ('raka-prizren', 1),
#  ('concretizing', 1),
#  ('colectiva', 1),
#  ('-ldc', 1),
#  ('taking care', 1),
#  ('igaraps', 1),
#  ('manarangi-trott', 1),
#  ('myriade', 1),
#  ('coordinators/resident', 1),
#  ('peopleindividuals', 1),
#  ('36/151', 1),
#  ('3992nd', 1),
#  ('61/282', 1),
#  ('bribr', 1),
#  ('in evidence', 1),
#  ('soft shoe', 1),
#  ('partnership-driven', 1),
#  ('school-', 1),
#  ('a/cn.4/578', 1),
#  ('commissioner-protection', 1),
#  ('a/49/965', 1),
#  ('goals.3', 1),
#  ('a.2', 1),
#  ('compactnamely', 1),
#  ('galdogob', 1),
#  ('suggestion.', 1),
#  ('103ter.', 1),
#  ('herzinsuffizienz', 1),
#  ('emergency-braking', 1),
#  ('kit-related', 1),
#  ('cat/c/34/add.17', 1),
#  ('33/55', 1),
#  ('a/hrc/wg.6/1/gbr/1', 1),
#  ('yihao', 1),
#  ('www.reliefweb.int/ocha_ol/programs/', 1),
#  ('manage/operate', 1),
#  ('505-506', 1),
#  ('cureafre', 1),
#  ('2000/11', 1),
#  ('comunicazioni', 1),
#  ('multi-industry', 1),
#  ('ordinances*', 1),
#  ('`disciplinary', 1),
#  ('a/61/525', 1),
#  ('souleliac', 1),
#  ('orletti', 1),
#  ('1424h', 1),
#  ('justice.', 1),
#  ('widows/widowers', 1),
#  ('s/prst/2000/4', 1),
#  ('two-edged', 1),
#  ('fao-executed', 1),
#  ('synergies.', 1),
#  ('099.3', 1),
#  ('person-hours', 1),
#  ('under-irrigation', 1),
#  ('soil-moisture', 1),
#  ('individualisation', 1),
#  ('chmar', 1),
#  ('productivity-enhancing', 1),
#  ('ap2004/600/13/05', 1),
#  ('information/intelligence', 1),
#  ('food-supply', 1),
#  ('a/c.1/62/l.46/rev.1', 1),
#  ('non-profit-organizations', 1),
#  ('1978-iii', 1),
#  ('/07/1', 1),
#  ('healthmap', 1),
#  ('cchange', 1),
#  ('unjspf', 1),
#  ('longed-for', 1),
#  ('nuclear-weapon-capable', 1),
#  ('chaldo-assyrians', 1),
#  ('a/57/l.49', 1),
#  ('npt/conf.2000/4', 1),
#  ('a/54/405', 1),
#  ('28704', 1),
#  ('campuses.8', 1),
#  ('splos/123', 1),
#  ('l.g.d.j.', 1),
#  ('burcardine', 1),
#  ('slipper-making', 1),
#  ('c8-', 1),
#  ('a/cn.9/wg.vi/wp.29', 1),
#  ('hirey', 1),
#  ('-we', 1),
#  ('mhms', 1),
#  ('cotb', 1),
#  ('bde-209', 1),
#  ('repatriation/deportation', 1),
#  ('guurti', 1),
#  ('crc/c/65/add.36', 1),
#  ('yemtsov', 1),
#  ('alusik', 1),
#  ('halon-1301', 1),
#  ('e/conf.97/6/ip.3', 1),
#  ('18-39', 1),
#  ('al-sharqiya', 1),
#  ('baidowa', 1),
#  ('sna.j', 1),
#  ('non-bengalis', 1),
#  ('opies', 1),
#  ('trips-plus', 1),
#  ('prasartkul', 1),
#  ('non-factor', 1),
#  ('female.', 1),
#  ('al-rayah', 1),
#  ('maslukov', 1),
#  ('s/2001/883', 1),
#  ('k.s', 1),
#  ('inter-africa', 1),
#  ('feed-back', 1),
#  ('waste materials', 1),
#  ('one-year-olds', 1),
#  ('ministerialo', 1),
#  ('45/113', 1),
#  ('smpr', 1),
#  ('2.8.8', 1),
#  ('6.4.4', 1),
#  ('e/c.12/1/add.44', 1),
#  ('jpts', 1),
#  ('peoplesome', 1),
#  ('potait', 1),
#  ('1950-1985', 1),
#  ('a.9.3', 1),
#  ('agronomics', 1),
#  ('sub-tenant', 1),
#  ('63449-39-8', 1),
#  ('sit back', 1),
#  ('a/c.2/59/l.65', 1),
#  ('allocations.v', 1),
#  ('mrs. claire shaefer', 1),
#  ('rh/fp', 1),
#  ('a/c.5/61/l.53', 1),
#  ('gisc', 1),
#  ('less-costly', 1),
#  ('anaky', 1),
#  ('teto', 1),
#  ('power-based', 1),
#  ('s/2008/135', 1),
#  ('theft-related', 1),
#  ('a/58/108', 1),
#  ('56/292', 1),
#  ('injury/unnecessary', 1),
#  ('279-a', 1),
#  ('usurpia', 1),
#  ('procedure.i', 1),
#  ('2002-73', 1),
#  ('phonogrammes', 1),
#  ('e/cn.3/2001/crp.3', 1),
#  ('lawyer/suspect', 1),
#  ('sectoral-targeted', 1),
#  ('prisoners.', 1),
#  ('61/133', 1),
#  ('coherence.', 1),
#  ('-electric', 1),
#  ('maximum-effect', 1),
#  ('men.39', 1),
#  ('otwithstanding', 1),
#  ('ccpr/c/79/add.112', 1),
#  ('blight-proof', 1),
#  ('a/60/421', 1),
#  ('non-health-related', 1),
#  ('health-service-delivery', 1),
#  ('thick-skulled', 1),
#  ('repertory-related', 1),
#  ('inadmissible.', 1),
#  ('september-17', 1),
#  ('commodity-exporting', 1),
#  ('non-principal', 1),
#  ('a/c.2/59/l.11', 1),
#  ('non-persians', 1),
#  ('toes.', 1),
#  ('biosecutiry', 1),
#  ('unep/pops/poprc.4/inf/14', 1),
#  ('poorly-educated', 1),
#  ('horse race', 1),
#  ('5.111', 1),
#  ('h11', 1),
#  ('~25', 1),
#  ('institutions-unmik', 1),
#  ('rafeeudin', 1),
#  ('commercial enterprise', 1),
#  ('2004/27', 1),
#  ('philadephi', 1),
#  ('giudiziari', 1),
#  ('ministerie', 1),
#  ('al-raeiya', 1),
#  ('eepmp', 1),
#  ('methodologies.the', 1),
#  ('e/incb/2008/4', 1),
#  ('price/profit', 1),
#  ('jubayl', 1),
#  ('51-92', 1),
#  ('//www.livelihoods.org/lessons/project_summaries/supp4_projsum.html', 1),
#  ('progression.', 1),
#  ('borsod-abaj-zempln', 1),
#  ('ngyke', 1),
#  ('aperans', 1),
#  ('specially-equipped', 1),
#  ('kamituga', 1),
#  ('condoms.', 1),
#  ('tarje', 1),
#  ('unep/pops/cop.1', 1),
#  ('cut down', 1),
#  ('2004/35', 1),
#  ('non-confirmation', 1),
#  ('torch-bearer', 1),
#  ('survey-paic', 1),
#  ('e/cn.6/2000/pg/2', 1),
#  ('not-in-kind', 1),
#  ('william a. bill shea', 1),
#  ('3.b.1', 1),
#  ('59/213', 1),
#  ('thrombosed', 1),
#  ('approximately130', 1),
#  ('el-bashir', 1),
#  ('committee.24', 1),
#  ('1998/409/gbvb', 1),
#  ('2005-june', 1),
#  ('aba/ceeli', 1),
#  ('e/c.12/q/geo/1', 1),
#  ('household-type', 1),
#  ('student-built', 1),
#  ('27654', 1),
#  ('gnassingb', 1),
#  ('vessels.', 1),
#  ('aznainizam', 1),
#  ('operates.17', 1),
#  ('1960-1999', 1),
#  ('a/cn.9/wg.iii/wp.36', 1),
#  ('measles.', 1),
#  ('kherbane', 1),
#  ('sniffing-', 1),
#  ('cerd/c/65/co/5', 1),
#  ('2000/2001-2002/2003', 1),
#  ('nordnorsk', 1),
#  ('963-8737', 1),
#  ('alighieris', 1),
#  ('9251', 1),
#  ('irrp', 1),
#  ('a/cn.4/595', 1),
#  ('1999.55', 1),
#  ('development/agriculture', 1),
#  ('rudyard kipling', 1),
#  ('185000', 1),
#  ('accountability.', 1),
#  ('chuck-a-luck', 1),
#  ('grand jury', 1),
#  ('e/cn.9/2008/4', 1),
#  ('x.10', 1),
#  ('jrme', 1),
#  ('hammam-', 1),
#  ('a/59/523', 1),
#  ('twofold.', 1),
#  ...]

# %%
with open('million_unknown_words.pickle', 'wb') as f:
    pickle.dump(unknown_words, f)
